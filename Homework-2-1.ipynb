# %%
# Print graph and equilibrium distance of argon dimer potential

import optimize_argon_dimer           # Imports argon dimer python file
# %run optimize_argon_dimer.py          # Runs argon dimer python file
# Out:
# The equilibrium distance for Ar₂ occurs at 3.816 Angstroms

# %%
# Print graph of argon trimer potential

import optimize_argon_trimer          # Imports argon trimer python file
# %run optimize_argon_trimer.py         # Runs argon trimer python file
# Out:
# Optimized coordinates (r12, x3, y3): (3.816, 1.908, 3.305)
# Minimum potential energy: -0.030
# The optimized distances (Angstroms) are r12: 3.816, r13: 3.816, r23: 3.816
# The optimal angles between the Ar atoms are: Atom 1: 60.000°, Atom 2: 60.000°, Atom 3: 60.000°
# Given the equal distances between each atom and three 60 degree internal angles, the optimized geometry is an equilateral triangle

# %%
# Print xyz file of argon dimer and trimer geometries
# x, y, z coordinates are in Angstroms, dimer consists of 2 Ar atoms, trimer consists of 3 Ar atoms

print(f"""
2
Argon Dimer
Ar  0.000000    0.000000     0.000000
Ar  0.000000    3.816349     0.000000

3
Argon Trimer
Ar  0.000000    0.000000     0.000000
Ar  3.816349    0.000000     0.000000
Ar  1.908144    3.305054     0.000000""")
# Out:
# 2
# Argon Dimer
# Ar  0.000000    0.000000     0.000000
# Ar  0.000000    3.816349     0.000000
#
# 3
# Argon Trimer
# Ar  0.000000    0.000000     0.000000
# Ar  3.816349    0.000000     0.000000
# Ar  1.908144    3.305054     0.000000
